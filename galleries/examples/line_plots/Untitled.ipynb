# %%
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4]
y1 = [1, 4, 9, 16]
y2 = [1, 2, 3, 4]

fig, ax = plt.subplots()
line1, = ax.plot(x, y1, 'o', label='Quadratic')
line2, = ax.plot(x, y2, 's', label='Linear')

# Create legend
legend = ax.legend()

# Adjust the size of the legend handles
for handle in legend.legend_handles:
    print(handle.__dict__)
#     handle._sizes = [20]  # Change the size to your desired value

# for i, key in enumerate(leg.legend_handles):
#     print(
#     leg.legendHandles[i]._sizes = [20]

# plt.show()

# legend.__dict__()
# Out:
# {'_stale': True, 'stale_callback': <function _stale_axes_callback at 0x7f84e57b8790>, '_axes': <Axes: >, 'figure': <Figure size 640x480 with 1 Axes>, '_transform': <matplotlib.transforms.CompositeAffine2D object at 0x7f84e4715ae0>, '_transformSet': True, '_visible': True, '_animated': False, '_alpha': None, 'clipbox': None, '_clippath': None, '_clipon': True, '_label': 'Quadratic', '_picker': None, '_rasterized': False, '_agg_filter': None, '_mouseover': False, '_callbacks': <matplotlib.cbook.CallbackRegistry object at 0x7f84e4715c60>, '_remove_method': None, '_url': None, '_gid': None, '_snap': None, '_sketch': None, '_path_effects': [], '_sticky_edges': _XYPair(x=[], y=[]), '_in_layout': True, '_dashcapstyle': <CapStyle.butt: 'butt'>, '_dashjoinstyle': <JoinStyle.round: 'round'>, '_solidjoinstyle': <JoinStyle.round: 'round'>, '_solidcapstyle': <CapStyle.projecting: 'projecting'>, '_linestyles': None, '_drawstyle': 'default', '_linewidth': 1.5, '_unscaled_dash_pattern': (0, None), '_dash_pattern': (0.0, None), '_linestyle': 'None', '_invalidx': True, '_color': '#1f77b4', '_marker': <matplotlib.markers.MarkerStyle object at 0x7f84e4715c30>, '_gapcolor': None, '_markevery': [1], '_markersize': 6.0, '_antialiased': True, '_markeredgecolor': 'auto', '_markeredgewidth': 1.0, '_markerfacecolor': 'auto', '_markerfacecoloralt': 'none', '_pickradius': 5, 'ind_offset': 0, '_xorig': array([ 0., 10., 20.]), '_yorig': array([3.5, 3.5, 3.5]), '_invalidy': True, '_x': None, '_y': None, '_xy': None, '_path': None, '_transformed_path': None, '_subslice': False, '_x_filled': None}
# {'_stale': True, 'stale_callback': <function _stale_axes_callback at 0x7f84e57b8790>, '_axes': <Axes: >, 'figure': <Figure size 640x480 with 1 Axes>, '_transform': <matplotlib.transforms.CompositeAffine2D object at 0x7f84e47160b0>, '_transformSet': True, '_visible': True, '_animated': False, '_alpha': None, 'clipbox': None, '_clippath': None, '_clipon': True, '_label': 'Linear', '_picker': None, '_rasterized': False, '_agg_filter': None, '_mouseover': False, '_callbacks': <matplotlib.cbook.CallbackRegistry object at 0x7f84e4716230>, '_remove_method': None, '_url': None, '_gid': None, '_snap': None, '_sketch': None, '_path_effects': [], '_sticky_edges': _XYPair(x=[], y=[]), '_in_layout': True, '_dashcapstyle': <CapStyle.butt: 'butt'>, '_dashjoinstyle': <JoinStyle.round: 'round'>, '_solidjoinstyle': <JoinStyle.round: 'round'>, '_solidcapstyle': <CapStyle.projecting: 'projecting'>, '_linestyles': None, '_drawstyle': 'default', '_linewidth': 1.5, '_unscaled_dash_pattern': (0, None), '_dash_pattern': (0.0, None), '_linestyle': 'None', '_invalidx': True, '_color': '#ff7f0e', '_marker': <matplotlib.markers.MarkerStyle object at 0x7f84e4716200>, '_gapcolor': None, '_markevery': [1], '_markersize': 6.0, '_antialiased': True, '_markeredgecolor': 'auto', '_markeredgewidth': 1.0, '_markerfacecolor': 'auto', '_markerfacecoloralt': 'none', '_pickradius': 5, 'ind_offset': 0, '_xorig': array([ 0., 10., 20.]), '_yorig': array([3.5, 3.5, 3.5]), '_invalidy': True, '_x': None, '_y': None, '_xy': None, '_path': None, '_transformed_path': None, '_subslice': False, '_x_filled': None}

# %%
legend.__dict__
# Out:
# {'_stale': False,
#  'stale_callback': <function matplotlib.artist._stale_axes_callback(self, val)>,
#  '_axes': <Axes: >,
#  'figure': <Figure size 640x480 with 1 Axes>,
#  '_transform': <matplotlib.transforms.IdentityTransform at 0x7f84e4c25150>,
#  '_transformSet': False,
#  '_visible': True,
#  '_animated': False,
#  '_alpha': None,
#  'clipbox': None,
#  '_clippath': None,
#  '_clipon': True,
#  '_label': '',
#  '_picker': None,
#  '_rasterized': False,
#  '_agg_filter': None,
#  '_mouseover': False,
#  '_callbacks': <matplotlib.cbook.CallbackRegistry at 0x7f84e4d99db0>,
#  '_remove_method': <bound method Axes._remove_legend of <Axes: >>,
#  '_url': None,
#  '_gid': None,
#  '_snap': None,
#  '_sketch': None,
#  '_path_effects': [],
#  '_sticky_edges': _XYPair(x=[], y=[]),
#  '_in_layout': True,
#  'prop': <matplotlib.font_manager.FontProperties at 0x7f84e4c241f0>,
#  '_fontsize': 10.0,
#  'texts': [Text(0, 0, 'Quadratic'), Text(0, 0, 'Linear')],
#  'legend_handles': [<matplotlib.lines.Line2D at 0x7f84e4c26290>,
#   <matplotlib.lines.Line2D at 0x7f84e4c253c0>],
#  '_legend_title_box': <matplotlib.offsetbox.TextArea at 0x7f84e4c24d30>,
#  '_custom_handler_map': None,
#  'numpoints': 1,
#  'markerscale': 1.0,
#  'scatterpoints': 1,
#  'borderpad': 0.4,
#  'labelspacing': 0.5,
#  'handlelength': 2.0,
#  'handleheight': 0.7,
#  'handletextpad': 0.8,
#  'borderaxespad': 0.5,
#  'columnspacing': 2.0,
#  'shadow': False,
#  '_ncols': 1,
#  '_scatteryoffsets': array([0.375]),
#  '_legend_box': <matplotlib.offsetbox.VPacker at 0x7f84e4c25060>,
#  'isaxes': True,
#  'parent': <Axes: >,
#  '_mode': None,
#  '_bbox_to_anchor': None,
#  '_shadow_props': {'ox': 2, 'oy': -2},
#  'legendPatch': <matplotlib.patches.FancyBboxPatch at 0x7f84e4c25630>,
#  '_alignment': 'center',
#  '_legend_handle_box': <matplotlib.offsetbox.HPacker at 0x7f84e4c26020>,
#  '_loc_used_default': True,
#  '_outside_loc': None,
#  '_loc_real': 0,
#  '_draggable': None}

# %%
import matplotlib as plt

# Sample data
x = [1, 2, 3, 4]
y1 = [1, 4, 9, 16]
y2 = [1, 2, 3, 4]

fig, ax = plt.subplots()
line1, = ax.plot(x, y1, 'o', label='Quadratic')
line2, = ax.plot(x, y2, 's', label='Linear')

# Create legend
legend = ax.legend()

# Adjust the size of the legend handles
for handle in legend.legendHandles:
    handle._sizes = [50]  # Change the size to your desired value

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 8
#       5 y1 = [1, 4, 9, 16]
#       6 y2 = [1, 2, 3, 4]
# ----> 8 fig, ax = plt.subplots()
#       9 line1, = ax.plot(x, y1, 'o', label='Quadratic')
#      10 line2, = ax.plot(x, y2, 's', label='Linear')
#
# File /scratch1/NCEPDEV/da/Kevin.Dougherty/pyenv/EMCPy/lib/python3.10/site-packages/matplotlib/_api/__init__.py:217, in caching_module_getattr.<locals>.__getattr__(name)
#     215 if name in props:
#     216     return props[name].__get__(instance)
# --> 217 raise AttributeError(
#     218     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'subplots'
